# %% [markdown]
# # Synthetic Privacy Risk Lab
#
# Run the command below from the repository root to generate privacy-risk outputs using fictional documents only.

# %%
# !python scripts/run_synthetic_privacy_lab.py --documents 70 --seed 42

# %% [markdown]
# Review generated files under `outputs/results`, `outputs/reports`, `outputs/figures`, and `outputs/audit`. Do not use real private documents in this synthetic lab.
